# %% [markdown]
# <a href="https://colab.research.google.com/github/siriberman/Laboratorio_Tema_2/blob/main/Laboratorio_Entregable_2_Sesiones_6_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Parte 1: Introducción a Python
#Escribir un programa que reciba una lista de números enteros y determine la cantidad de números pares e impares.
for num in range(1, 20):
  if num % 2 == 0:
    print(f"{num} es par")
  else:
    print(f"{num} es impar")
# Out:
# 1 es impar
# 2 es par
# 3 es impar
# 4 es par
# 5 es impar
# 6 es par
# 7 es impar
# 8 es par
# 9 es impar
# 10 es par
# 11 es impar
# 12 es par
# 13 es impar
# 14 es par
# 15 es impar
# 16 es par
# 17 es impar
# 18 es par
# 19 es impar

# %%
#Parte 2: Manipulación de datos con Pandas y NumPy
#Carga y exploración inicial de datos:
#•Importar el archivo CSV que se entrega en el laboratorio.
#•Explorar datos con funciones como .head(), .info(), y .describe().
import pandas as pd
df = pd.read_csv('CSV Laboratorio 2 AD-B.csv')
print(df.head(10))
# Out:
#   Producto      Mes Sucursal  Precio_unitario  Cantidad_vendida
# 0        A    Enero    Norte            15.24                45
# 1        A    Enero      Sur            92.37                11
# 2        A    Enero     Este            49.81                29
# 3        A    Enero    Oeste            31.58                36
# 4        A  Febrero    Norte            18.45                25
# 5        A  Febrero      Sur            26.46                21
# 6        A  Febrero     Este            94.12                36
# 7        A  Febrero    Oeste            67.44                10
# 8        A    Marzo    Norte            56.50                37
# 9        A    Marzo      Sur            69.14                 9

# %%
#Parte 2: Manipulación de datos con Pandas y NumPy
#Transformación de datos:
#•Crear una nueva columna llamada “Ingresos Totales”
import pandas as pd
df = pd.read_csv('CSV Laboratorio 2 AD-B.csv')
df['Ingresos Totales'] = df['Precio_unitario'] * df['Cantidad_vendida']
print(df.head(10))
# Out:
#   Producto      Mes Sucursal  Precio_unitario  Cantidad_vendida  \
# 0        A    Enero    Norte            15.24                45
# 1        A    Enero      Sur            92.37                11
# 2        A    Enero     Este            49.81                29
# 3        A    Enero    Oeste            31.58                36
# 4        A  Febrero    Norte            18.45                25
# 5        A  Febrero      Sur            26.46                21
# 6        A  Febrero     Este            94.12                36
# 7        A  Febrero    Oeste            67.44                10
# 8        A    Marzo    Norte            56.50                37
# 9        A    Marzo      Sur            69.14                 9
#
#    Ingresos Totales
# 0            685.80
# 1           1016.07
# 2           1444.49
# 3           1136.88
# 4            461.25
# 5            555.66
# 6           3388.32
# 7            674.40
# 8           2090.50
# 9            622.26

# %%
#•Filtrar datos según una condición (Filtrar aquellos productos de los que se haya vendido más de 40 unidades)
import pandas as pd
df = pd.read_csv('CSV Laboratorio 2 AD-B.csv')
ventas_filtradas = df[df['Cantidad_vendida'] > 40]
print(ventas_filtradas)
# Out:
#    Producto      Mes Sucursal  Precio_unitario  Cantidad_vendida
# 0         A    Enero    Norte            15.24                45
# 12        A    Abril    Norte            14.29                49
# 14        A    Abril     Este            24.28                48
# 17        B    Enero      Sur            18.26                49
# 25        B    Marzo      Sur            41.17                49
# 30        B    Abril     Este            89.80                41
# 33        C    Enero      Sur            94.01                49
# 35        C    Enero    Oeste            58.54                48
# 40        C    Marzo    Norte            88.05                49
# 43        C    Marzo    Oeste            70.95                41
# 52        D  Febrero    Norte            34.66                47
# 63        D    Abril    Oeste            54.64                45

# %%
#•Filtrar los 10 precios más altos
import pandas as pd
df = pd.read_csv('CSV Laboratorio 2 AD-B.csv')
precios_mas_altos = df.nlargest(10, 'Precio_unitario')
print(precios_mas_altos)
# Out:
#    Producto      Mes Sucursal  Precio_unitario  Cantidad_vendida
# 20        B  Febrero    Norte            98.16                24
# 29        B    Abril      Sur            95.42                35
# 39        C  Febrero    Oeste            94.98                19
# 38        C  Febrero     Este            94.95                13
# 6         A  Febrero     Este            94.12                36
# 33        C    Enero      Sur            94.01                49
# 1         A    Enero      Sur            92.37                11
# 30        B    Abril     Este            89.80                41
# 40        C    Marzo    Norte            88.05                49
# 47        C    Abril    Oeste            83.86                 7

# %%
#Parte 3: Visualización de datos con Matplotlib y Seaborn

#Gráficos básicos con Matplotlib:
#•	Crear un gráfico de barras que agrupe las ventas por sucursal y mes, y sume las cantidades vendidas

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('CSV Laboratorio 2 AD-B.csv')

plt.figure(figsize=(12, 6))
plt.bar(ventas_agrupadas['Sucursal'] + '-' + ventas_agrupadas['Mes'], ventas_agrupadas['Cantidad_vendida'])

plt.xlabel('Sucursal - Mes')
plt.ylabel('Cantidad_vendida')
plt.title('Ventas por Sucursal y Mes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#Parte 3: Visualización de datos con Matplotlib y Seaborn

#Gráficos básicos con Matplotlib:
#•Crear un gráfico de dispersión para mostrar la relación entre las columnas “Precio Unitario” y “Cantidad Vendida”

import pandas as pd
df = pd.read_csv('CSV Laboratorio 2 AD-B.csv')

# Crea el gráfico de dispersión
plt.figure(figsize=(8, 6))
plt.scatter(df['Precio_unitario'], df['Cantidad_vendida'])
plt.xlabel('Precio_unitario')
plt.ylabel('Cantidad_vendida')
plt.title('Relación entre Precio_unitario y Cantidad_vendida')
plt.grid(True)
plt.show()
